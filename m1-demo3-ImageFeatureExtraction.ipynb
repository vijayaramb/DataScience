# %%
import cv2

# %%
imagePath = './data/Vj.jpg'
image = cv2.imread(imagePath)

# %%
import matplotlib
import matplotlib.pyplot as plt

# !matplotlib inline
plt.imshow(image)
# Out:
# 'matplotlib' is not recognized as an internal or external command,
# operable program or batch file.

# %%
image.shape
# Out:
# (485, 378, 3)

# %%
image
# Out:
# array([[[123, 121, 121],
#         [134, 132, 132],
#         [146, 146, 146],
#         ...,
#         [255, 254, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[138, 136, 136],
#         [124, 122, 122],
#         [130, 130, 130],
#         ...,
#         [255, 253, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[139, 140, 138],
#         [135, 136, 134],
#         [130, 131, 129],
#         ...,
#         [255, 254, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[251, 253, 255],
#         [250, 253, 255],
#         [251, 254, 255],
#         ...,
#         [255, 254, 255],
#         [255, 254, 255],
#         [255, 254, 255]],
#
#        [[251, 254, 255],
#         [249, 252, 255],
#         [251, 254, 255],
#         ...,
#         [255, 254, 254],
#         [255, 253, 255],
#         [255, 253, 255]],
#
#        [[251, 253, 254],
#         [253, 255, 255],
#         [253, 255, 255],
#         ...,
#         [255, 255, 254],
#         [255, 255, 255],
#         [255, 254, 255]]], dtype=uint8)

# %%
image[0][0]
# Out:
# array([123, 121, 121], dtype=uint8)

# %%
size=(32,32)
resized_image_feature_vector = cv2.resize(image,size)

# %%
plt.imshow(resized_image_feature_vector)

# %%
resized_image_feature_vector.shape
# Out:
# (32, 32, 3)

# %%
resized_image_feature_vector
# Out:
# array([[[157, 164, 160],
#         [143, 157, 151],
#         [149, 160, 157],
#         ...,
#         [108, 125, 121],
#         [114, 143, 135],
#         [108, 103, 112]],
#
#        [[135, 133, 135],
#         [147, 156, 154],
#         [178, 203, 201],
#         ...,
#         [108, 142, 135],
#         [ 97, 125, 116],
#         [123, 121, 126]],
#
#        [[128, 118, 125],
#         [152, 177, 171],
#         [140, 170, 166],
#         ...,
#         [111, 149, 143],
#         [214, 241, 238],
#         [177, 197, 195]],
#
#        ...,
#
#        [[225, 209, 202],
#         [220, 206, 204],
#         [250, 251, 255],
#         ...,
#         [153, 112, 109],
#         [128,  85, 198],
#         [145, 117, 142]],
#
#        [[199, 211, 232],
#         [240, 246, 254],
#         [198, 205, 221],
#         ...,
#         [153, 112, 110],
#         [149, 103, 174],
#         [148, 111, 199]],
#
#        [[199, 211, 223],
#         [244, 250, 253],
#         [236, 224, 243],
#         ...,
#         [155, 108, 108],
#         [141,  96, 197],
#         [124,  98, 155]]], dtype=uint8)

# %%
resized_flattened_image_feature_vector = resized_image_feature_vector.flatten()

# %%
resized_flattened_image_feature_vector
# Out:
# array([157, 164, 160, ..., 124,  98, 155], dtype=uint8)

# %%
len(resized_flattened_image_feature_vector)
# Out:
# 3072

# %%
image_grayscale = cv2.imread(imagePath,cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(image_grayscale)

# %%
image_grayscale.shape
# Out:
# (485, 378)

# %%
image_grayscale
# Out:
# array([[121, 132, 146, ..., 255, 255, 255],
#        [136, 122, 130, ..., 254, 255, 255],
#        [139, 135, 130, ..., 255, 255, 255],
#        ...,
#        [255, 254, 255, ..., 255, 255, 255],
#        [255, 253, 255, ..., 254, 255, 255],
#        [253, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
import numpy as np
expanded_image_greyscale = np.expand_dims(image_grayscale,axis=2)
expanded_image_greyscale.shape
# Out:
# (485, 378, 1)

# %%
expanded_image_greyscale
# Out:
# array([[[121],
#         [132],
#         [146],
#         ...,
#         [255],
#         [255],
#         [255]],
#
#        [[136],
#         [122],
#         [130],
#         ...,
#         [254],
#         [255],
#         [255]],
#
#        [[139],
#         [135],
#         [130],
#         ...,
#         [255],
#         [255],
#         [255]],
#
#        ...,
#
#        [[255],
#         [254],
#         [255],
#         ...,
#         [255],
#         [255],
#         [255]],
#
#        [[255],
#         [253],
#         [255],
#         ...,
#         [254],
#         [255],
#         [255]],
#
#        [[253],
#         [255],
#         [255],
#         ...,
#         [255],
#         [255],
#         [255]]], dtype=uint8)
